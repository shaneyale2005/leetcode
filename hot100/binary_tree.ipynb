# %% [markdown]
# # [Leetcode94-二叉树的中序遍历](https://leetcode.cn/problems/binary-tree-inorder-traversal/?envType=study-plan-v2&envId=top-100-liked)
#
# 给定一个二叉树的根节点root，返回它的中序遍历。
#
# ```cpp
# // 下面是使用Cpp实现的
# class Solution {
# public:
#     vector<int> res;
#
#     void inOrder(TreeNode *root) {
#         if (!root) {
#             return;
#         }
#         inOrder(root->left);
#         res.push_back(root->val);
#         inOrder(root->right);
#     }
#
#     vector<int> inorderTraversal(TreeNode *root) {
#         inOrder(root);
#         return res;
#     }
# };
# ```

# %%
# Definition for a binary tree node.
# class TreeNode:
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right
class Solution:
    def inorderTraversal(self, root: Optional[TreeNode]) -> List[int]:
        res = []
        def inOrder(root):
            if not root:
                return
            inOrder(root.left)
            res.append(root.val)
            inOrder(root.right)
        inOrder(root)
        return res

# %% [markdown]
# # [Leetcode104-二叉树的最大深度](https://leetcode.cn/problems/maximum-depth-of-binary-tree/description/?envType=study-plan-v2&envId=top-100-liked)
#
# 给定一个二叉树root，返回其最大深度。二叉树的最大深度是指从根节点到最远叶子节点的最长路径上的节点数。
#
# ```cpp
# // 使用Cpp进行求解
# // 深度优先搜索
# class Solution {
# public:
#     int maxDepth(TreeNode *root) {
#         if (!root) {return 0;}
#         int leftDepth = maxDepth(root->left);
#         int rightDepth = maxDepth(root->right);
#         return std::max(leftDepth, rightDepth) + 1;
#     }
# };
# ```

# %%
# 树的dfs模版
def dfs(node):
    # 想好终止的条件
    if not node:
        return
    # 执行想要的操作
    do_something(node)
    # 处理左右节点
    dfs(node.left)
    dfs(node.right)

# %%
# 对比图或网格的dfs模版
def dfs(x, y):
    if 越界 or 已经访问:
        return 
    # 加入
    visited[x][y] = True
    # 处理事情
    do_something(x, y)

    for dx, dy in directions:
        dfs(x + dx, y + dy)

# %%
# 回溯型的dfs
def dfs(path, choices):
    if 满足结束条件:
        res.append(path[:])
        return 
    for choice in choices:
        path.append(choice)
        dfs(path, new_choices)
        path.pop()

# %%
class Solution:
    def maxDepth(self, root):
        if not root:
            return 0
        left = self.maxDepth(root.left)
        right = self.maxDepth(root.right)
        return max(right, left) + 1

# %% [markdown]
# # [Leetcode226-翻转二叉树](https://leetcode.cn/problems/invert-binary-tree/description/?envType=study-plan-v2&envId=top-100-liked)
#
# 给你一棵二叉树的根节点root，翻转这棵二叉树，并返回其根节点。
#
# ```cpp
# // 使用Cpp进行求解
# class Solution {
# public:
#     TreeNode* invertTree(TreeNode *root) {
#         if (!root) { return nullptr; }
#         root->left = right;
#         root->right = left;
#         left = invertTree(root->left);
#         right = invertTree(root->right);
#
#         return root;
#     }
# };
# ```

# %%
# 使用Py进行求解
class Solution:
    def invertTree(self, root):
        if not root:
            return None
        # 先序遍历递归
        root.left = right
        root.right = left
        left = self.invertTree(root.left)
        right = self.invertTree(root.right)

        return root

# %% [markdown]
# # [Leetcode101-对称二叉树](https://leetcode.cn/problems/symmetric-tree/description/?envType=study-plan-v2&envId=top-100-liked)
#
# 给你一个二叉树的根节点root， 检查它是否轴对称。
#
# ```cpp
# // 使用Cpp进行求解
# class Solution {
# public:
#     bool isMirror(TreeNode *left, TreeNode *right) {
#         // 终止条件
#         if (left == nullptr && right == nullptr) {
#             return true;
#         }
#
#         // 一个为空，另一个不是空，不对称
#         if ((left && right == nullptr) || (right && left == nullptr)) {
#             return false;
#         }
#
#         // 节点的数值不相等，不对称
#         if (left->val != right->val) {
#             return false;
#         }
#
#         // 递归比较
#         return isMirror(left->left, right->right) && isMirror(left->right, right->left);
#     }
#
#     bool isSymmetric(TreeNode *root) {
#         // 判断一棵树是否是对称的，等价于判断他的左子树和右子树是否是镜像对称的，可以使用递归
#         if (!root) { return true; }
#         return isMirror(root);
#     }
# };
# ```

# %%
# 使用Py进行求解
# Definition for a binary tree node.
class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

class Solution:
    def isSymmetric(self, root: Optional[TreeNode]) -> bool:
        if root is None:
            return True
        def isMirror(left, right):
            # 如果都是空，返回真
            if left is None and right is None:
                return True
            # 如果有一个为空，返回假
            if left and right is None or right and left is None:
                return False
            if left.val != right.val:
                return False
            
            return isMirror(left.left, right.right) and isMirror(left.right, right.left)
        return isMirror(root.left, root.right)

# %% [markdown]
# # [Leetcode543-二叉树的直径](https://leetcode.cn/problems/diameter-of-binary-tree/?envType=study-plan-v2&envId=top-100-liked)
#
# 给你一棵二叉树的根节点，返回该树的直径。
#
# 二叉树的直径是指树中任意两个节点之间最长路径的长度。这条路径可能经过也可能不经过根节点root。
#
# 两节点之间路径的长度由它们之间边数表示。
#
# ```cpp
# // 使用Cpp求解
# class Solution {
# private:
#     int ans = 0;
# public:
#     // 思路：针对任何一个root，经过它的最大直径是左子树的maxDepth加上右子树的maxDepth
#     int maxDepth(TreeNode *root) {
#         if (root == nullptr) {
#             return 0;
#         }
#         int left = maxDepth(root->left);
#         int right = maxDepth(root->right);
#         ans = std::max(left + right, ans);
#         return std::max(left, right) + 1;
#     }
#     int diameterOfBinaryTree(TreeNode *root) {
#         ans = 0;
#         maxDepth(root);
#         return ans;
#     }
# };
# ```

# %%
# 使用Py进行求解
class Solution:
    def diameterOfBinaryTree(self, root):
        self.ans = 0
        def depth(root):
            ans = 0
            if not root:
                return 0
            left = depth(root.left)
            right = depth(root.right)
            self.ans = max(left + right, self.ans)
            return max(left, right) + 1
        ans = depth(root)
        return self.ans

# %% [markdown]
# # [Leetcode102-二叉树的层序遍历](https://leetcode.cn/problems/binary-tree-level-order-traversal/description/?envType=study-plan-v2&envId=top-100-liked)
#
# 给你二叉树的根节点root，返回其节点值的层序遍历。
#
# ```cpp
# // 使用Cpp进行求解
# class Solution {
# public:
#     vector<vector<int>> levelOrder(TreeNode *root) {
#         // 常见的思路就是用队列来做
#         vector<vector<int>> res;
#         if (!root) {
#             return res;
#         }
#         queue<TreeNode*> q;
#         q.push(root);
#         while (!q.empty()) {
#             int levelSize = q.size();
#             vector<int> currentLevel;
#             for (int i = 0; i < levelSize; i++) {
#                 TreeNode *node = q.front();
#                 q.pop();
#                 currentLevel.push_back(node->val);
#                 if (node->left) {
#                     q.push(node->left);
#                 }
#                 if (node->right) {
#                     q.push(node->right);
#                 }
#             }
#             res.push_back(currentLevel);
#         }
#         return res;
#     }
# };
#
# ```

# %%
# 使用Py进行求解

from collections import deque

class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = None
        self.right = None
    
class Solution:
    def levelOrder(self, root):
        res = []
        if root is None:
            return res
        
        q = deque()
        q.append(root)
        while q:
            levelSize = len(q)
            currentLevel = []
            for i in range(levelSize):
                node = q.popleft()
                currentLevel.append(node.val)
                if node.left:
                    q.append(node.left)
                if node.right:
                    q.append(node.right)
            res.append(currentLevel)
        return res

# %% [markdown]
# # [Leetcode108-将有序数组转换为二叉搜索树](https://leetcode.cn/problems/convert-sorted-array-to-binary-search-tree/?envType=study-plan-v2&envId=top-100-liked)
#
# 给你一个整数数组nums，其中元素已经按升序排列，请你将其转换为一棵平衡二叉搜索树。
#
# ```cpp
# // Soluition in C++
# class Solution {
# private:
#     TreeNode *buildBST(vector<int> &nums, int left, int right) {
#         if (left > right) {
#             return nullptr;
#         }
#         int mid = left + (right - left) / 2;
#         TreeNode *root = new TreeNode(nums[mid]);
#         root->left = buildBST(nums, left, mid - 1);
#         root->right = buildBST(nums, mid + 1, right);
#         return root;
#     }
# public:
#     TreeNode *sortedArrayToBST(vector<int> &nums) {
#         return buildBST(nums, 0, nums.size() - 1);
#     }
# };
# ```

# %%
# Solution in Python
class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

class Solution:
    def sortedArrayToBST(self, nums):
        def buildBST(left, right):
            if left > right:
                return None
            mid = left + (right - left) // 2
            root = TreeNode(nums[mid])

            root.left = buildBST(left, mid - 1)
            root.right = buildBST(mid + 1, right)
            return root
        
        return buildBST(0, len(nums) - 1)

# %% [markdown]
# # [Leetcode98-验证二叉搜索树](https://leetcode.cn/problems/validate-binary-search-tree/description/?envType=study-plan-v2&envId=top-100-liked)
#
# 给定二叉树的根节点root，判断该二叉树是否为有效的二叉搜索树。
#
# 有效二叉搜索树的定义如下：
# - 节点的左子树中所有节点的值都严格小于当前节点的值；
# - 节点的右子树中所有节点的值都严格大于当前节点的值；
# - 该节点的左、右子树自身也必须是有效的二叉搜索树。
#
# ```cpp
# // 使用Cpp进行求解
# class Solution {
# public:
#     bool isValidBST(TreeNode *root) {
#
#     }
# };
#
# ```
