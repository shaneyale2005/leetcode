# %% [markdown]
# # [Leetcode 136. 只出现一次的数字](https://leetcode.cn/problems/single-number/submissions/717939700/?envType=study-plan-v2&envId=top-100-liked)

# %% [markdown]
# ```cpp
# // Solution in C++
# class Solution {
# public:
#     int singleNumber(vector<int>& nums) {
#         int ans = nums[0];
#         for (int i = 1; i < nums.size(); i++) {
#             ans = ans ^ nums[i];
#         }
#         return ans;
#     }
# };
# ```

# %%
# Solution in Python
class Solution:
    def singleNumber(self, nums):
        ans = nums[0]
        for i in range(1, len(nums)):
            ans = ans ^ nums[i]
        return ans

# %% [markdown]
# # [Leetcode 169. 多数元素](https://leetcode.cn/problems/majority-element/?envType=study-plan-v2&envId=top-100-liked)

# %% [markdown]
# ```cpp
# class Solution {
# public:
#     int majorityElement(vector<int>& nums) {
#         unordered_map<int,int> counts;
#         int n = nums.size();
#         for (int num : nums) {
#             counts[num]++;
#             if (counts[num] > n / 2) {
#                 return num;
#             }
#         }
#         return -1;
#     }
# };
# ```

# %%
from typing import List

class Solution:
    def majorityElement(self, nums: List[int]) -> int:
        counts = {}
        n = len(nums)
        for num in nums:
            counts[num] = counts.get(num, 0) + 1
            if counts[num] > n // 2:
                return num
        return -1

# %% [markdown]
# # [Leetcode 75. 颜色分类](https://leetcode.cn/problems/sort-colors/description/?envType=study-plan-v2&envId=top-100-liked)

# %% [markdown]
# ```cpp
# class Solution {
# public:
#     void sortColors(vector<int>& nums) {
#         int count[3] = {0, 0, 0};
#         for (int num : nums) {
#             count[num]++;
#         }
#         int index = 0;
#         for (int color = 0; color < 3; color++) {
#             while (count[color] != 0) {
#                 nums[index] = color;
#                 index++;
#                 count[color]--;
#             }
#         }
#     }
# };
# ```

# %%
from typing import List

class Solution:
    def sortColors(self, nums: List[int]) -> None:
        """
        Do not return anything, modify nums in-place instead.
        """
        count = [0, 0, 0]
        for num in nums:
            count[num] += 1
        index = 0
        for i in range(3):
            for _ in range(count[i]):
                nums[index] = i
                index += 1
        return nums
