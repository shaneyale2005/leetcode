# %% [markdown]
# # [Leetcode 121. 买卖股票的最佳时机](https://leetcode.cn/problems/best-time-to-buy-and-sell-stock/description/?envType=study-plan-v2&envId=top-100-liked)

# %% [markdown]
# ```cpp
# // Solution in C++
# #include <algorithm>
# #include <vector>
#
# class Solution {
# public:
#     int maxProfit(std::vector<int> &prices) {
#         int max_profit = 0;
#         int min_price = prices[0];
#
#         for (const int & price : prices) {
#             min_price = std::min(price, min_price);
#             int current_profit = price - min_price;
#             max_profit = std::max(max_profit, current_profit);
#         }
#
#         return max_profit;
#
#     }
# };
# ```

# %%
# Solution in Python

from typing import List

class Solution:
    def maxProfit(self, prices: List[int]) -> int:
        max_profit: int = 0
        min_price: int = prices[0]

        for price in prices:
            min_price = min(min_price, price)
            current_profit: int = price - min_price
            max_profit = max(max_profit, current_profit)

        return max_profit

# %% [markdown]
# # [Leetcode 55. 跳跃游戏](https://leetcode.cn/problems/jump-game/?envType=study-plan-v2&envId=top-100-liked)

# %% [markdown]
# ```cpp
# // Solution in C++
# #include <vector>
# #include <algorithm>
#
# class Solution {
# public:
#     bool canJump(std::vector<int> &nums) {
#         int n = nums.size();
#         int max_reach = 0;
#
#         for (int i = 0; i < n; i++) {
#             if (max_reach < i) {
#                 return false;
#             }
#             max_reach = std::max(max_reach, i + nums[i]);
#             if (max_reach >= n - 1) {
#                 return true;
#             }
#         }
#
#         return true;
#     }
# };
# ```

# %%
# Solution in Python
from typing import List

class Solution:
    def canJump(self, nums: List[int]) -> bool:
        n = len(nums)
        max_reach: int = 0 # max_reach 是一种索引
        for i in range(n):
            if i > max_reach:
                return False
            max_reach = max(max_reach, i + nums[i])
            if max_reach >= n - 1:
                return True
        return True
